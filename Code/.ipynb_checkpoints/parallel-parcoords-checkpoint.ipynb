# %%
from bokeh.io import show, output_notebook, output_file
from bokeh.models import GeoJSONDataSource, HoverTool, LinearColorMapper, ColumnDataSource, Circle
from bokeh.plotting import figure
from bokeh.palettes import Viridis11
import json
import pandas as pd

# %%
df = pd.read_csv('/Users/chuanxu/USF/module4/DV/final/DataViz/Data/Community_Resiliency_Indicator_System.csv')

# %%
df = df.drop(df.index[9]).sort_values('Res_Rank').reset_index().drop('index', axis=1)

# %%
df
# Out:
#                  Neighborhood  Flood_Per  Heat_Per   Liq_Per  Haz_Score  \
# 0                    Presidio   0.029715  0.000000  0.189915        4.0
# 1         Castro/Upper Market   0.000000  0.002686  0.119483        5.0
# 2                  Noe Valley   0.000000  0.000446  0.029884        5.0
# 3              Haight Ashbury   0.000000  0.061487  0.070927        4.0
# 4   Diamond Heights/Glen Park   0.000000  0.000279  0.198020        4.0
# 5                    Seacliff   0.037849  0.000000  0.298043        3.0
# 6             Pacific Heights   0.000000  0.326841  0.015976        3.0
# 7          West of Twin Peaks   0.000000  0.002537  0.079822        5.0
# 8                      Marina   0.007152  0.000000  0.526522        2.0
# 9                Inner Sunset   0.000000  0.000000  0.109439        5.0
# 10           Presidio Heights   0.000000  0.145970  0.000000        4.0
# 11                 Twin Peaks   0.000000  0.000000  0.168995        4.0
# 12               Potrero Hill   0.010071  0.735680  0.360947        2.0
# 13               Russian Hill   0.002798  0.232177  0.143669        3.0
# 14             Inner Richmond   0.000000  0.058091  0.007004        5.0
# 15             Bernal Heights   0.000000  0.104888  0.129120        3.0
# 16                Mission Bay   0.132514  0.970396  0.956101        1.0
# 17             Outer Richmond   0.015642  0.067941  0.018275        5.0
# 18                   Nob Hill   0.000000  0.859125  0.032282        2.0
# 19               Outer Sunset   0.017670  0.000000  0.107834        5.0
# 20           Western Addition   0.000000  0.546090  0.040024        2.0
# 21                   Parkside   0.009789  0.000000  0.052155        5.0
# 22                  Lakeshore   0.008689  0.000000  0.126072        4.0
# 23                North Beach   0.011395  0.595815  0.567130        1.0
# 24                    Mission   0.000000  0.781198  0.313797        2.0
# 25              Outer Mission   0.000000  0.389407  0.036636        2.0
# 26                 Ocean View   0.000000  0.104212  0.035932        4.0
# 27            South of Market   0.002380  0.999957  0.746064        1.0
# 28                  Excelsior   0.000000  0.345133  0.022647        3.0
# 29             Crocker Amazon   0.000000  0.218043  0.019277        3.0
# 30         Financial District   0.026447  0.674863  0.802687        1.0
# 31        Treasure Island/YBI   0.262905  0.000000  0.792697        2.0
# 32          Visitacion Valley   0.000000  0.251304  0.033395        3.0
# 33      Downtown/Civic Center   0.000000  0.999767  0.153798        1.0
# 34                    Bayview   0.068369  0.586532  0.557273        1.0
# 35                  Chinatown   0.000000  0.999761  0.312332        1.0
#
#      Imp_Per  Tree_Per  PM_Conc   Tox_Per  Env_Score    ...     NonWhi_Per  \
# 0   0.201173  0.327813  8.24549  0.134241        5.0    ...       0.175061
# 1   0.655799  0.145122  8.44600  0.000597        4.0    ...       0.189934
# 2   0.651473  0.154978  8.35925  0.000000        4.0    ...       0.211936
# 3   0.635759  0.201023  8.62574  0.000325        4.0    ...       0.249671
# 4   0.433316  0.240678  8.31805  0.006081        5.0    ...       0.321564
# 5   0.228907  0.292767  8.08114  0.103440        5.0    ...       0.313694
# 6   0.701965  0.139228  8.43993  0.000256        4.0    ...       0.208502
# 7   0.517343  0.174997  8.27451  0.000000        5.0    ...       0.438003
# 8   0.699011  0.097604  8.52847  0.196404        2.0    ...       0.165051
# 19  0.054143        NaN   0.580475  0.222907  19472.10    14960.80        2.0
# 20  0.109336   0.160793   0.192511  0.334236  34121.10    25633.70        3.0
# 21  0.067322        NaN   0.554463  0.227874  18120.80    17576.20        2.0
# 22  0.107989   0.050102   0.337396  0.311442   5349.84     6686.27        3.0
# 23  0.080849        NaN   0.385926  0.339620  20251.00    60634.40        2.0
# 24  0.386371   0.039016   0.137722  0.331993  31818.30    51745.80        3.0
# 25  0.274013        NaN   0.452213  0.260247  20054.10    18027.40        1.0
# 26  0.180296   0.107951   0.485469  0.281643  21384.70    21085.90        2.0
# 27  0.113717   0.071615   0.335331  0.349859  22658.10   107755.00        3.0
# 28  0.300063   0.030812   0.463785  0.294074  23767.50    21733.00        1.0
# 29  0.229331   0.038749   0.582375  0.287790  28187.10    26867.70        1.0
# 30       NaN        NaN   0.342407  0.553725   9940.64   113954.00        1.0
# 31  0.181527        NaN   0.177929  0.567773   3241.93     2963.89        2.0
# 32  0.179246   0.144478   0.561015  0.436356  16164.40    12421.50        1.0
# 33  0.155041   0.079329   0.313486  0.561498  65411.70   101040.00        2.0
# 34  0.237667   0.341864   0.293999  0.413469   6944.77     9850.25        1.0
# 35       NaN        NaN   0.830267  0.657467  70416.60   278476.00        1.0
#
#     Res_Score  Res_Rank
# 0         5.0       1.0
# 1         5.0       2.0
# 2         5.0       3.0
# 3         5.0       4.0
# 4         5.0       5.0
# 5         5.0       6.0
# 6         5.0       7.0
# 7         5.0       8.0
# 8         4.0       9.0
# 9         4.0      10.0
# 10        4.0      11.0
# 11        4.0      12.0
# 12        4.0      13.0
# 13        4.0      14.0
# 14        4.0      15.0
# 15        3.0      16.0
# 16        3.0      17.0
# 17        3.0      18.0
# 18        3.0      19.0
# 19        3.0      20.0
# 20        3.0      21.0
# 21        3.0      22.0
# 22        2.0      23.0
# 23        2.0      24.0
# 24        2.0      25.0
# 25        2.0      26.0
# 26        2.0      27.0
# 27        2.0      28.0
# 28        2.0      29.0
# 29        1.0      30.0
# 30        1.0      31.0
# 31        1.0      32.0
# 32        1.0      33.0
# 33        1.0      34.0
# 34        1.0      35.0
# 35        1.0      36.0
#
# [36 rows x 51 columns]

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go


data = [
    go.Parcoords(
        line = dict(color = df['Res_Score'],
                   colorscale = [[1,'#eff3ff'],[2,'#bdd7e7'],[3,'#6baed6'], [4,'#3182bd'], [5,'#08519c']]),
        dimensions = list([
            dict(range = [1,5],
                label = 'Hazard Risk', values = df['Haz_Score']),
            dict(range = [1,5],
                label = 'Environmental', values = df['Env_Score']),
            dict(range = [1,5],
                label = 'Transportation', values = df['Trans_Score']),
            dict(range = [1,5],
                label = 'Community', values = df['Com_Score']),
            dict(range = [1,5],
                label = 'Public Realm', values = df['PR_Score']),
            dict(range = [1,5],
                label = 'Housing Resiliency', values = df['House_Score']),
            dict(range = [1,5],
                label = 'Economy', values = df['Ec_Score']),
            dict(range = [1,5],
                label = 'Demographic', values = df['Dem_Score']),
            dict(range = [1,5],
                label = 'Resiliency Score', values = df['Res_Score']),
            dict(range = [36,1],
                tickvals = df.index + 1,
                ticktext = df['Neighborhood'],
                label = 'Resiliency  Rank', values = df['Res_Rank'])
        ])
    )
]

layout = go.Layout(
    plot_bgcolor = '#ffffff',
    paper_bgcolor = '#ffffff',
    height = 800
    
)

fig = go.Figure(data = data, layout = layout)
plotly.offline.plot(fig, filename = 'parcoords-basic.html')
# Out:
# 'file:///Users/chuanxu/Desktop/DataViz/Code/parcoords-basic.html'
